# %%
import torch

# 1. Is PyTorch loaded?
print(f"PyTorch Version: {torch.__version__}")

# 2. Can it see your GPU?
if torch.cuda.is_available():
    print("SUCCESS: AI System Ready on GPU! 🟢")
else:
    print("System Ready on CPU (Standard Mode). ⚪")
# Out:
# PyTorch Version: 2.9.0+cpu
# System Ready on CPU (Standard Mode). ⚪

# %% [markdown]
# retele neuronale
#
# backward propagation
#
# gradient decent
#
#
# ce face micrograd
#
#
# mnist - poate de facut
